# %%
import os
import numpy as np
import pandas as pd

from pyopenms import MSExperiment, MzMLFile
from concurrent.futures import ProcessPoolExecutor
from tqdm import tqdm
from matplotlib import pyplot as plt
import pickle

from mzml_pdiff import load_from_csv
from mzml_pdiff import save_to_csv
from mzml_pdiff import process_file

# %%
num_peaks_dict = pickle.load(open("data/results_dict_ms1.pkl", "rb"))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#plt.figure(figsize=(6.4, 3))

dia_key = "LFQ_Orbitrap_AIF_Human_01.mzML"
dda_key = "LFQ_Orbitrap_DDA_Human_01.mzML"

plt.hist(
    num_peaks_dict[dda_key],
    bins=list(range(0, 260)),
    color="blue",
    alpha=0.5,
    label="DDA Orbitrap",
)
plt.hist(
    num_peaks_dict[dia_key],
    bins=list(range(0, 260)),
    color="red",
    alpha=0.5,
    label="DIA Orbitrap",
)

plt.title("MS1 peaks in a spectrum")

plt.legend()
plt.xlabel("Peaks in spectrum (#)")
plt.ylabel("Frequency (#)")
plt.tight_layout()
plt.savefig("img/ms1_peaks_lfq_orbitrap.svg")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6.4, 3))

dia_key = "LFQ_TTOF6600_SWATH_Human_01.mzML"
dda_key = "LFQ_TTOF6600_DDA_Human_01.mzML"

plt.hist(
    num_peaks_dict[dda_key],
    bins=list(range(0, 260)),
    color="blue",
    alpha=0.5,
    label="DDA TTOF6600",
)
plt.hist(
    num_peaks_dict[dia_key],
    bins=list(range(0, 260)),
    color="red",
    alpha=0.5,
    label="DIA TTOF6600",
)
plt.legend()
plt.title("MS1 peaks in a spectrum")
plt.xlabel("Peaks in spectrum (#)")
plt.ylabel("Frequency (#)")
plt.tight_layout()
plt.savefig("img/ms1_peaks_ttof6600.svg")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6.4, 3))

dia_key = "LFQ_timsTOFPro_diaPASEF_Human_01.mzML"
dda_key = "LFQ_timsTOFPro_PASEF_Human_01.mzML"

plt.hist(
    num_peaks_dict[dda_key],
    bins=list(range(0, 260)),
    color="blue",
    alpha=0.5,
    label="DDA PASEF timsTOFPro",
)
plt.hist(
    num_peaks_dict[dia_key],
    bins=list(range(0, 260)),
    color="red",
    alpha=0.5,
    label="DIA diaPASEF timsTOFPro",
)
plt.legend()
plt.title("MS1 peaks in a spectrum")
plt.xlabel("Peaks in spectrum (#)")
plt.ylabel("Frequency (#)")
plt.tight_layout()
plt.savefig("img/ms1_peaks_timsTOFPro.svg")
plt.show()
